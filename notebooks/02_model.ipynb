# %%
import pandas as pd
import joblib
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler,PolynomialFeatures

# %%
data=pd.read_csv('../data/cleaned_data.csv')
data
# Out:
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.985611        40.735943         -73.980331
# 1             -73.978394        40.764351         -73.991623
# 2             -73.989059        40.744389         -73.973381
# 3             -73.990326        40.731136         -73.991264
# 4             -73.969833        40.768570         -73.962646
# ...                  ...              ...                ...
# 925901        -73.959106        40.771770         -73.953995
# 925902        -73.970978        40.764015         -73.956230
# 925903        -73.982178        40.771240         -73.970749
# 925904        -73.982513        40.765533         -74.005974
# 925905        -73.970810        40.761436         -73.991852
#
#         dropoff_latitude  trip_duration  pickup_hour  pickup_dayofweek  \
# 0              40.760468       6.947937            7                 2
# 1              40.749859       6.719013           12                 6
# 2              40.748692       6.421622            2                 6
# 3              40.748917       6.766192           17                 3
# 4              40.767181       5.926926           12                 3
# ...                  ...            ...          ...               ...
# 925901         40.786312       5.541264           15                 4
# 925902         40.777851       6.075346           19                 2
# 925903         40.758968       7.175490            8                 3
# 925904         40.711842       7.748460           14                 0
# 925905         40.734692       7.096721           11                 2
#
#         pickup_month  distance
# 0                  6  1.325230
# 1                  4  1.084912
# 2                  6  0.877455
# 3                  5  1.091473
# 4                  4  0.485277
# ...              ...       ...
# 925901             3  0.983298
# 925902             5  1.090979
# 925903             5  0.982033
# 925904             4  1.986360
# 925905             2  1.495615
#
# [925906 rows x 9 columns]

# %%
X=data.drop('trip_duration',axis=1)
y=data['trip_duration']

# %%
# Define the pipeline
model = Pipeline([
        ('poly', PolynomialFeatures(degree=3)),
        ('scaler', MinMaxScaler()),
        ('ridge', Ridge(alpha=0.1))
])

# %%
# Train the model
model.fit(X, y)
# Out:
# Pipeline(steps=[('poly', PolynomialFeatures(degree=3)),
#                 ('scaler', MinMaxScaler()), ('ridge', Ridge(alpha=0.1))])

# %%
# evaluation
y_pred = model.predict(X)
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)

# %%
# Print the results
print(f"Train R² Score: {r2*100:.2f} %, MSE: {mse:.4f}")
# Out:
# Train R² Score: 63.25 %, MSE: 0.1517

# %%
joblib.dump(model, '../models/model.pkl')
# Out:
# ['model.pkl']
